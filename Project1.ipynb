# %% [markdown]
# <a href="https://colab.research.google.com/github/LittleBopeep2020/Python_Class/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('https://data.cityofnewyork.us/resource/csps-2ne9.json')

# %%
df.head()
# Out:
#   school_dbn                     school_name       school_type school_level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt  General Academic          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt  General Academic          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt  General Academic          K-8
# 3     01M140          P.S. 140 Nathan Straus  General Academic          K-8
# 4     01M140          P.S. 140 Nathan Straus  General Academic          K-8
#
#           regents_exam  year demographic_category demographic_variable  \
# 0  Common Core Algebra  2017         All Students         All Students
# 1   Living Environment  2015         All Students         All Students
# 2   Living Environment  2016         All Students         All Students
# 3  Common Core Algebra  2016         All Students         All Students
# 4  Common Core Algebra  2017         All Students         All Students
#
#    total_tested mean_score number_scoring_below_65 percent_scoring_below_65  \
# ...

# %%
df.tail()
# Out:
#     school_dbn                               school_name       school_type  \
# 995     02M408  Professional Performing Arts High School  General Academic
# 996     02M408  Professional Performing Arts High School  General Academic
# 997     02M408  Professional Performing Arts High School  General Academic
# 998     02M408  Professional Performing Arts High School  General Academic
# 999     02M408  Professional Performing Arts High School  General Academic
#
#          school_level          regents_exam  year demographic_category  \
# 995  Secondary School   Common Core Algebra  2015         All Students
# 996  Secondary School   Common Core Algebra  2016         All Students
# 997  Secondary School   Common Core Algebra  2017         All Students
# 998  Secondary School  Common Core Algebra2  2016         All Students
# 999  Secondary School  Common Core Algebra2  2017         All Students
#
#     demographic_variable  total_tested mean_score number_scoring_below_65  \
# ...

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.columns
# Out:
# Index(['school_dbn', 'school_name', 'school_type', 'school_level',
#        'regents_exam', 'year', 'demographic_category', 'demographic_variable',
#        'total_tested', 'mean_score', 'number_scoring_below_65',
#        'percent_scoring_below_65', 'number_scoring_65_or_above',
#        'percent_scoring_65_or_above', 'number_scoring_80_or_above',
#        'percent_scoring_80_or_above', 'number_scoring_cr',
#        'percent_scoring_cr'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     school_dbn                               school_name       school_type  \
# 0       01M034            P.S. 034 Franklin D. Roosevelt  General Academic
# 1       01M034            P.S. 034 Franklin D. Roosevelt  General Academic
# 2       01M034            P.S. 034 Franklin D. Roosevelt  General Academic
# 3       01M140                    P.S. 140 Nathan Straus  General Academic
# 4       01M140                    P.S. 140 Nathan Straus  General Academic
# ..         ...                                       ...               ...
# 995     02M408  Professional Performing Arts High School  General Academic
# 996     02M408  Professional Performing Arts High School  General Academic
# 997     02M408  Professional Performing Arts High School  General Academic
# 998     02M408  Professional Performing Arts High School  General Academic
# 999     02M408  Professional Performing Arts High School  General Academic
#
# ...

# %%
df.isnull().sum()
# Out:
# school_dbn                     0
# school_name                    0
# school_type                    0
# school_level                   0
# regents_exam                   0
# year                           0
# demographic_category           0
# demographic_variable           0
# total_tested                   0
# mean_score                     0
# number_scoring_below_65        0
# percent_scoring_below_65       0
# number_scoring_65_or_above     0
# percent_scoring_65_or_above    0
# number_scoring_80_or_above     0
# percent_scoring_80_or_above    0
# number_scoring_cr              0
# percent_scoring_cr             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
pd.isna(df['number_scoring_cr'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: number_scoring_cr, Length: 1000, dtype: bool

# %%
pd.isna(df['number_scoring_cr']).count()
# Out:
# 1000

# %%
df.isna(df['number_scoring_cr']).count().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0f0ae38f417d> in <cell line: 1>()
# ----> 1 df.isna(df['number_scoring_cr']).count().sort_values(ascending=False)
#
# TypeError: DataFrame.isna() takes 1 positional argument but 2 were given
