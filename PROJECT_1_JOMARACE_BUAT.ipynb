# %% [markdown]
# <a href="https://colab.research.google.com/github/littlebopeep23/Python_Class/blob/main/PROJECT_1_JOMARACE_BUAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
missing_values = ['na','s']
#Kimberly helped me get rid of the 'na' and 's' from the data.

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/csps-2ne9.csv',na_values=missing_values)
df = df.dropna()

# %%
#My initial plan was to compare at least 5 schools with their ALGEBRA Regents scores.
#I ended up comparing 4 schools with their ALGEBRA and ENGLISH Regents score.
#My goal is to compare at least 5 schools and look for the highest average score for Algebra and English Regents.

# %%
df.head()
# Out:
#    school_dbn                 school_name       school_type school_level  \
# 8      01M184        P.S. 184m Shuang Wen  General Academic          K-8
# 9      01M184        P.S. 184m Shuang Wen  General Academic          K-8
# 10     01M184        P.S. 184m Shuang Wen  General Academic          K-8
# 12     01M188  P.S. 188 The Island School  General Academic          K-8
# 13     01M188  P.S. 188 The Island School  General Academic          K-8
#
#            regents_exam  year demographic_category demographic_variable  \
# 8   Common Core Algebra  2015         All Students         All Students
# 9   Common Core Algebra  2016         All Students         All Students
# 10  Common Core Algebra  2017         All Students         All Students
# 12  Common Core Algebra  2015         All Students         All Students
# 13  Common Core Algebra  2016         All Students         All Students
#
#     total_tested  mean_score  number_scoring_below_65  \
# ...

# %%
df.tail()
# Out:
#     school_dbn                               school_name       school_type  \
# 995     02M408  Professional Performing Arts High School  General Academic
# 996     02M408  Professional Performing Arts High School  General Academic
# 997     02M408  Professional Performing Arts High School  General Academic
# 998     02M408  Professional Performing Arts High School  General Academic
# 999     02M408  Professional Performing Arts High School  General Academic
#
#          school_level          regents_exam  year  total_tested  mean_score  \
# 995  Secondary School   Common Core Algebra  2015           113          67
# 996  Secondary School   Common Core Algebra  2016           121          75
# 997  Secondary School   Common Core Algebra  2017            96          80
# 998  Secondary School  Common Core Algebra2  2016            58          66
# 999  Secondary School  Common Core Algebra2  2017            60          69
#
#      number_scoring_below_65  percent_scoring_below_65  \
# ...

# %%
df.shape
# Out:
# (485, 18)

# %%
df.columns
# Out:
# Index(['school_dbn', 'school_name', 'school_type', 'school_level',
#        'regents_exam', 'year', 'demographic_category', 'demographic_variable',
#        'total_tested', 'mean_score', 'number_scoring_below_65',
#        'percent_scoring_below_65', 'number_scoring_65_or_above',
#        'percent_scoring_65_or_above', 'number_scoring_80_or_above',
#        'percent_scoring_80_or_above', 'number_scoring_cr',
#        'percent_scoring_cr'],
#       dtype='object')

# %%
df.isnull()
df.isnull().sum().sum()
#data cleaning, prior to drop "missing_values".
# Out:
# 0

# %%
df.dropna()
# Out:
#     school_dbn                               school_name       school_type  \
# 8       01M184                      P.S. 184m Shuang Wen  General Academic
# 9       01M184                      P.S. 184m Shuang Wen  General Academic
# 10      01M184                      P.S. 184m Shuang Wen  General Academic
# 12      01M188                P.S. 188 The Island School  General Academic
# 13      01M188                P.S. 188 The Island School  General Academic
# ..         ...                                       ...               ...
# 995     02M408  Professional Performing Arts High School  General Academic
# 996     02M408  Professional Performing Arts High School  General Academic
# 997     02M408  Professional Performing Arts High School  General Academic
# 998     02M408  Professional Performing Arts High School  General Academic
# 999     02M408  Professional Performing Arts High School  General Academic
#
# ...

# %%
df.shape
# Out:
# (485, 18)

# %% [markdown]
# DROPPING COLUMNS

# %%
df.drop('demographic_category',axis=1,inplace=True)

# %%
df.drop('demographic_variable',axis=1,inplace=True)

# %%
df.shape
# Out:
# (485, 16)

# %%
#DATA EXPLORATION

# %%
df.groupby(['year'])['year'].count().sort_index(ascending=True)
# Out:
# year
# 2015    173
# 2016    179
# 2017    133
# Name: year, dtype: int64

# %%
df.groupby(['school_name'])['school_name'].count().sort_index(ascending=True)
# Out:
# school_name
# 47 The American Sign Language and English Secondar    20
# Bard High School Early College                         6
# Battery Park City School                               3
# Business Of Sports School                             16
# Cascades High School                                  10
# East Side Community School                             6
# East Side Middle School                                3
# Emma Lazarus High School                              18
# Essex Street Academy                                   5
# Facing History School, The                             5
# Food and Finance High School                          16
# Forsyth Satellite Academy                              7
# Gramercy Arts High School                             19
# High School for Environmental Studies                 19
# High School of Hospitality Management                 13
# I.S. 289                                               2
# ...

# %%
df.groupby(['school_name'])['school_name'].count().sort_values(ascending=False)
# Out:
# school_name
# 47 The American Sign Language and English Secondar    20
# University Neighborhood High School                   20
# Gramercy Arts High School                             19
# The High School For Language And Diplomacy            19
# High School for Environmental Studies                 19
# Urban Assembly School of Design and Construction,     18
# Lower East Side Preparatory High School               18
# MANHATTAN BUSINESS ACADEMY                            18
# Emma Lazarus High School                              18
# New Explorations into Science, Technology and Math    17
# Urban Assembly School of Business for Young Women,    17
# Pace High School                                      17
# Business Of Sports School                             16
# Marta Valle High School                               16
# Food and Finance High School                          16
# Urban Assembly Academy of Government and Law, The     15
# ...

# %%
df.groupby(['school_level'])['school_level'].count().sort_index(ascending=True)
# Out:
# school_level
# High school                        405
# Junior High-Intermediate-Middle     26
# K-12 all grades                     17
# K-8                                 13
# Secondary School                    24
# Name: school_level, dtype: int64

# %%
df.groupby(['regents_exam'])['regents_exam'].count().sort_index(ascending=True)
# Out:
# regents_exam
# Algebra2/Trigonometry     50
# Common Core Algebra      126
# Common Core Algebra2      41
# Common Core English       83
# Common Core Geometry      66
# English                   47
# Geometry                  35
# Integrated Algebra        37
# Name: regents_exam, dtype: int64

# %%
df.groupby(['regents_exam'])['regents_exam'].count().sort_values(ascending=False)
# Out:
# regents_exam
# Common Core Algebra      126
# Common Core English       83
# Common Core Geometry      66
# Algebra2/Trigonometry     50
# English                   47
# Common Core Algebra2      41
# Integrated Algebra        37
# Geometry                  35
# Name: regents_exam, dtype: int64

# %%
#SELECTING 5 SCHOOLS

# %%
#Filtering Rows

# %%
df[df['school_name'] == 'High School for Environmental Studies']
df_HSES= df[df['school_name'] == 'High School for Environmental Studies']
df_HSES.count() #38
df_HSES
# Out:
#     school_dbn                            school_name       school_type  \
# 945     02M400  High School for Environmental Studies  General Academic
# 946     02M400  High School for Environmental Studies  General Academic
# 947     02M400  High School for Environmental Studies  General Academic
# 948     02M400  High School for Environmental Studies  General Academic
# 949     02M400  High School for Environmental Studies  General Academic
# 950     02M400  High School for Environmental Studies  General Academic
# 951     02M400  High School for Environmental Studies  General Academic
# 952     02M400  High School for Environmental Studies  General Academic
# 954     02M400  High School for Environmental Studies  General Academic
# 955     02M400  High School for Environmental Studies  General Academic
# 956     02M400  High School for Environmental Studies  General Academic
# 957     02M400  High School for Environmental Studies  General Academic
# ...

# %%
df_HSES[df['school_level']=='High school']
All_HS_df_HSES  = df_HSES[df['school_level']=='High school']
All_HS_df_HSES
# Out:
# <ipython-input-26-c105f985d7bf>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_HSES[df['school_level']=='High school']
# <ipython-input-26-c105f985d7bf>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSES  = df_HSES[df['school_level']=='High school']
#     school_dbn                            school_name       school_type  \
# 945     02M400  High School for Environmental Studies  General Academic
# 946     02M400  High School for Environmental Studies  General Academic
# 947     02M400  High School for Environmental Studies  General Academic
# 948     02M400  High School for Environmental Studies  General Academic
# 949     02M400  High School for Environmental Studies  General Academic
# 950     02M400  High School for Environmental Studies  General Academic
# 951     02M400  High School for Environmental Studies  General Academic
# ...

# %%
#Fuzzy Matching

# %%
All_HS_df_HSES[df['regents_exam'].str.contains('Algebra')]
HSES_Algebra = All_HS_df_HSES[df['regents_exam'].str.contains('Algebra')]
HSES_Algebra
# Out:
# <ipython-input-28-e39c167d3520>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSES[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-28-e39c167d3520>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HSES_Algebra = All_HS_df_HSES[df['regents_exam'].str.contains('Algebra')]
#     school_dbn                            school_name       school_type  \
# 945     02M400  High School for Environmental Studies  General Academic
# 946     02M400  High School for Environmental Studies  General Academic
# 947     02M400  High School for Environmental Studies  General Academic
# 948     02M400  High School for Environmental Studies  General Academic
# 949     02M400  High School for Environmental Studies  General Academic
# 950     02M400  High School for Environmental Studies  General Academic
# 951     02M400  High School for Environmental Studies  General Academic
# ...

# %%
#Second School

# %%
df[df['school_name'] == 'University Neighborhood High School']
df_UNHS = df[df['school_name'] == 'University Neighborhood High School']
df_UNHS.count() #37
df_UNHS

df_UNHS[df['school_level']=='High school']
All_HS_df_UNHS  = df_UNHS[df['school_level']=='High school']
All_HS_df_UNHS

All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
UNHS_Algebra = All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
UNHS_Algebra
# Out:
# <ipython-input-30-55337bc25300>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_UNHS[df['school_level']=='High school']
# <ipython-input-30-55337bc25300>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_UNHS  = df_UNHS[df['school_level']=='High school']
# <ipython-input-30-55337bc25300>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-30-55337bc25300>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   UNHS_Algebra = All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
#    school_dbn                          school_name       school_type  \
# 60     01M448  University Neighborhood High School  General Academic
# 61     01M448  University Neighborhood High School  General Academic
# 62     01M448  University Neighborhood High School  General Academic
# ...

# %%
df[df['school_name'] == 'The High School For Language And Diplomacy']
df_HSLD = df[df['school_name'] == 'The High School For Language And Diplomacy']
df_HSLD.count() #36
df_HSLD

df_HSLD[df['school_level']=='High school']
All_HS_df_HSLD  = df_HSLD[df['school_level']=='High school']
All_HS_df_HSLD

All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
HSLD_Algebra = All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
HSLD_Algebra
# Out:
# <ipython-input-31-123f84f531d9>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_HSLD[df['school_level']=='High school']
# <ipython-input-31-123f84f531d9>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSLD  = df_HSLD[df['school_level']=='High school']
# <ipython-input-31-123f84f531d9>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-31-123f84f531d9>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HSLD_Algebra = All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
#     school_dbn                                 school_name       school_type  \
# 908     02M399  The High School For Language And Diplomacy  General Academic
# 909     02M399  The High School For Language And Diplomacy  General Academic
# ...

# %%
HSLD_Algebra = HSLD_Algebra.drop(930,axis=0)
# I did this to drop the specific rows with 's', prior to dropping "missing_values"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3372c1fccdaa> in <cell line: 1>()
# ----> 1 HSLD_Algebra = HSLD_Algebra.drop(930,axis=0)
#       2 # I did this to drop the specific rows with 's', prior to dropping "missing_values"
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
# Third School

# %%
df[df['school_name'] == 'Gramercy Arts High School']
df_GAHS = df[df['school_name'] == 'Gramercy Arts High School']
df_GAHS

df_GAHS[df['school_level']=='High school']
All_HS_df_GAHS = df_GAHS[df['school_level']=='High school']
All_HS_df_GAHS

All_HS_df_GAHS[df['regents_exam'].str.contains('Algebra')]
GAHS_Algebra = All_HS_df_GAHS[df['regents_exam'].str.contains('Algebra')]
GAHS_Algebra
# Out:
# <ipython-input-34-aa4425fb1934>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_GAHS[df['school_level']=='High school']
# <ipython-input-34-aa4425fb1934>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_GAHS = df_GAHS[df['school_level']=='High school']
# <ipython-input-34-aa4425fb1934>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_GAHS[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-34-aa4425fb1934>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   GAHS_Algebra = All_HS_df_GAHS[df['regents_exam'].str.contains('Algebra')]
#     school_dbn                school_name       school_type school_level  \
# 749     02M374  Gramercy Arts High School  General Academic  High school
# 750     02M374  Gramercy Arts High School  General Academic  High school
# ...

# %%
df[df['school_name'] == 'The High School for Language And Diplomacy']
df_HSLD = df[df['school_name'] == 'The High School for Language And Diplomacy']
df_HSLD

df_HSLD[df['school_level']=='High school']
All_HS_df_HSLD = df_HSLD[df['school_level']=='High school']
All_HS_df_HSLD

All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
HSLD_Algebra = All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
HSLD_Algebra
# Out:
# <ipython-input-35-b0b722f02cd7>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_HSLD[df['school_level']=='High school']
# <ipython-input-35-b0b722f02cd7>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSLD = df_HSLD[df['school_level']=='High school']
# <ipython-input-35-b0b722f02cd7>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-35-b0b722f02cd7>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HSLD_Algebra = All_HS_df_HSLD[df['regents_exam'].str.contains('Algebra')]
# Empty DataFrame
# ...

# %%
# Fifth School

# %%
df[df['school_name'] == 'Pace High School']
df_PHS = df[df['school_name'] == 'Pace High School']
df_PHS

df_PHS[df['school_level']=='High school']
All_HS_df_PHS = df_PHS[df['school_level']=='High school']
All_HS_df_PHS

All_HS_df_PHS[df['regents_exam'].str.contains('Algebra')]
PHS_Algebra = All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
PHS_Algebra
# Out:
# <ipython-input-37-a903b58035e3>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_PHS[df['school_level']=='High school']
# <ipython-input-37-a903b58035e3>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_PHS = df_PHS[df['school_level']=='High school']
# <ipython-input-37-a903b58035e3>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   All_HS_df_PHS[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-37-a903b58035e3>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   PHS_Algebra = All_HS_df_UNHS[df['regents_exam'].str.contains('Algebra')]
#    school_dbn                          school_name       school_type  \
# 60     01M448  University Neighborhood High School  General Academic
# 61     01M448  University Neighborhood High School  General Academic
# 62     01M448  University Neighborhood High School  General Academic
# ...

# %%
#SCHOOLS = ['High School for Environmental Studies', 'University Neighborhood High School', 'The High School For Language And Diplomacy', 'Gramercy Arts High School ', 'Pace High School']
#AVERAGES = ['HSES_Algebra'['mean_score'].mean(), 'UNHS_Algebra'['mean_score'].mean(),'HSLD_Algebra'['mean_score'].mean(),'GAHS_Algebra'['mean_score'].mean(), 'PHS_Algebra'['mean_score'].mean()]

# %%
#TypeError                                 Traceback (most recent call last)
#<ipython-input-81-fa83689d40e6> in <cell line: 2>()
#      1 SCHOOLS = ['High School for Environmental Studies', 'University Neighborhood High School', 'The High School For Language And Diplomacy', 'Gramercy Arts High School ', 'Pace High School']
#----> 2 AVERAGES = ['HSES_Algebra'['mean_score'].mean(), 'UNHS_Algebra'['mean_score'].mean(),'HSLD_Algebra'['mean_score'].mean(),'GAHS_Algebra'['mean_score'].mean(), 'PHS_Algebra'['mean_score'].mean()]

#TypeError: string indices must be integers


#This is where I found out that there are were more "s" and "na"'s. Eventhough, I ran df.isnull(), df.isnull().sum().sum(), and dropna.
#I also tried to convert the data frame into integers, but nothing happens.
# So, I dedcided to create subsets for my selected schools and it's average score.

# %%
print(df.dtypes)
# Out:
# school_dbn                      object
# school_name                     object
# school_type                     object
# school_level                    object
# regents_exam                    object
# year                             int64
# total_tested                     int64
# mean_score                     float64
# number_scoring_below_65        float64
# percent_scoring_below_65       float64
# number_scoring_65_or_above     float64
# percent_scoring_65_or_above    float64
# number_scoring_80_or_above     float64
# percent_scoring_80_or_above    float64
# number_scoring_cr              float64
# percent_scoring_cr             float64
# dtype: object

# %%
df['school_name'].unique()
# Out:
# array(['P.S. 184m Shuang Wen', 'P.S. 188 The Island School',
#        'Orchard Collegiate Academy', 'School for Global Leaders',
#        'University Neighborhood High School',
#        'East Side Community School', 'Forsyth Satellite Academy',
#        'Marta Valle High School',
#        'Lower East Side Preparatory High School',
#        'New Explorations into Science, Technology and Math',
#        'Cascades High School', 'Bard High School Early College',
#        'Tompkins Square Middle School',
#        '47 The American Sign Language and English Secondar',
#        'J.H.S. 104 Simon Baruch', 'East Side Middle School',
#        'P.S. 126 Jacob August Riis', 'M.S. 131',
#        'The Urban Assembly School for Emergency Management',
#        'Stephen T. Mather Building Arts & Craftsmanship Hi',
#        'J.H.S. 167 Robert F. Wagner', 'Yorkville East Middle School',
#        'P.S./I.S. 217 Roosevelt Island',
#        'M.S. 255 Salk School of Science',
# ...

# %%
df['mean_score'] = df['mean_score'].astype(int)

# %%
SCHOOLS = ['High School for Environmental Studies', 'University Neighborhood High School', 'The High School For Language And Diplomacy', 'Gramercy Arts High School ', 'Pace High School']
#SELECTED_SCHOOLS = df[df['school_name'].isin(SCHOOLS)]

# %%
SELECTED_SCHOOLS = df.loc[df['school_name'].isin(SCHOOLS)]

# %%
AVERAGES = df.loc[df['mean_score'].isin(SCHOOLS)]
#['HSES_Algebra'['mean_score'].mean(), 'UNHS_Algebra'['mean_score'].mean(),'HSLD_Algebra'['mean_score'].mean(),'GAHS_Algebra'['mean_score'].mean(), 'PHS_Algebra'['mean_score'].mean()]

# %%
SELECTED_SCHOOLS['mean_score'] = SELECTED_SCHOOLS['mean_score'].astype(int)
# Out:
# <ipython-input-46-5d3ca839c5bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SELECTED_SCHOOLS['mean_score'] = SELECTED_SCHOOLS['mean_score'].astype(int)

# %%
SELECTED_SCHOOLS.groupby(['school_name'])['mean_score'].mean().sort_values(ascending=False)
# Out:
# school_name
# Pace High School                              65.764706
# University Neighborhood High School           64.550000
# High School for Environmental Studies         62.315789
# The High School For Language And Diplomacy    61.315789
# Name: mean_score, dtype: float64

# %%
SELECTED_SCHOOLS.groupby(['school_name'])['mean_score'].mean().sort_values(ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='school_name'>

# %%
SELECTED_SCHOOLS.head()
# Out:
#    school_dbn                          school_name       school_type  \
# 60     01M448  University Neighborhood High School  General Academic
# 61     01M448  University Neighborhood High School  General Academic
# 62     01M448  University Neighborhood High School  General Academic
# 63     01M448  University Neighborhood High School  General Academic
# 64     01M448  University Neighborhood High School  General Academic
#
#    school_level           regents_exam  year  total_tested  mean_score  \
# 60  High school  Algebra2/Trigonometry  2015            45          62
# 61  High school  Algebra2/Trigonometry  2016            55          59
# 62  High school  Algebra2/Trigonometry  2017            11          58
# 63  High school    Common Core Algebra  2015           105          62
# 64  High school    Common Core Algebra  2016           148          68
#
#     number_scoring_below_65  percent_scoring_below_65  \
# 60                     21.0                      46.7
# ...

# %%
SELECTED_SCHOOLS[df['regents_exam'].str.contains('Algebra')]
Algebra_Schools = SELECTED_SCHOOLS[df['regents_exam'].str.contains('Algebra')]
Algebra_Schools
Algebra_Schools.groupby(['school_name'])['mean_score'].count().sort_values(ascending=False)
# Out:
# <ipython-input-50-778aa50adf3e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SELECTED_SCHOOLS[df['regents_exam'].str.contains('Algebra')]
# <ipython-input-50-778aa50adf3e>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Algebra_Schools = SELECTED_SCHOOLS[df['regents_exam'].str.contains('Algebra')]
# school_name
# High School for Environmental Studies         10
# University Neighborhood High School           10
# The High School For Language And Diplomacy     9
# Pace High School                               8
# Name: mean_score, dtype: int64

# %%
Algebra_Schools.groupby(['school_name'])['mean_score'].count().sort_values(ascending=True).plot(kind='barh', color='purple')
# Out:
# <Axes: ylabel='school_name'>

# %%
SELECTED_SCHOOLS[df['regents_exam'].str.contains('English')]
English_Schools = SELECTED_SCHOOLS[df['regents_exam'].str.contains('English')]
English_Schools
English_Schools.groupby(['school_name'])['mean_score'].count().sort_values(ascending=False)
# Out:
# <ipython-input-52-f9f3f0c5cc23>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SELECTED_SCHOOLS[df['regents_exam'].str.contains('English')]
# <ipython-input-52-f9f3f0c5cc23>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   English_Schools = SELECTED_SCHOOLS[df['regents_exam'].str.contains('English')]
# school_name
# The High School For Language And Diplomacy    5
# University Neighborhood High School           5
# High School for Environmental Studies         4
# Pace High School                              4
# Name: mean_score, dtype: int64

# %%
English_Schools.groupby(['school_name'])['mean_score'].count().sort_values(ascending=True).plot(kind='barh', color='red')
# Out:
# <Axes: ylabel='school_name'>

# %% [markdown]
# In conclusion, the analysis of Algebra and English Regents scores across multiple schools has provided valuable insights into the academic performance and strengths of each institution. The data shows that, University Neighborhood High School has the highest average score for both Algebra and English Regents. While Pace High School got the lowest average score for Algebra and High School for Environment Studies also has the lowest average score for English Regents score.
#
# The comparison of Regents scores serves as a starting point for meaningful discussions on how to enhance educational outcomes and create a positive impact on the academic journey of students.
#
# It is important to note that Regents scores alone may not capture the full spectrum of educational excellence, and this data is inaccurate due to lacking of core subject requirements for both Algebra and English Regents readiness.
